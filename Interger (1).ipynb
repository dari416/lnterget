# %% [markdown]
# # **integer 1** ⚓

# %%
L = int(input("введите расстояние в см: "))
meters = L // 100
print(f'количество полных метров: {meters}')
# Out:
# введите расстояние в см: 1456
# количество полных метров: 14

# %% [markdown]
# ### integer ***2***

# %%
M = int(input("введите массу в килограмах: "))
tons = M // 1000
print(f'количество полных тонн: {tons}')
# Out:
# введите массу в килограмах:  167
# количество полных тонн: 0

# %% [markdown]
# # integer 3

# %%
size_in_bytes = int(input('введите размер файла в байтах: '))
kb = size_in_bytes
