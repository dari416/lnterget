# %% [markdown]
# # **integer 1** ⚓

# %%
L = int(input("введите расстояние в см: "))
meters = L // 100
print(f'количество полных метров: {meters}')
# Out:
# введите расстояние в см: 1456
# количество полных метров: 14

# %% [markdown]
# ### integer ***2***

# %%
M = int(input("введите массу в килограмах: "))
tons = M // 1000
print(f'количество полных тонн: {tons}')
# Out:
# введите массу в килограмах:  167
# количество полных тонн: 0

# %% [markdown]
# # integer 3

# %%
size_in_bytes = int(input('введите размер файла в байтах: '))
kb = size_in_bytes

# %% [markdown]
# 4

# %%
A = int(input("Введите длину отрезка A: "))
B = int(input("Введите длину отрезка B: "))
count = A // B
print("Количество отрезков B, размещенных на отрезке A:", count)
# Out:
# Введите длину отрезка A: 10
# Введите длину отрезка B: 5
# Количество отрезков B, размещенных на отрезке A: 2

# %% [markdown]
# 5

# %%
A = int(input())
B = int(input())
remainder = A % B
print(remainder)
# Out:
# 6
# 9
# 6

# %% [markdown]
# 6

# %%
N = int(input())
tens = N // 10
units = N % 10
print(tens)
print(units)
# Out:
# 100
# 10
# 0

# %% [markdown]
# 7

# %%
N = int(input())
tens = N // 10
units = N % 10
sum_digits = tens + units
prod_digts = tens * units
print(sum_digits)
print(prod_digts)
# Out:
# 100
# 10
# 0

# %% [markdown]
# 8

# %%
N = int(input())
tens = N // 10
units = N % 10
swapped = units * 10 + tens
print(swapped)
# Out:
# 100
# 10

# %% [markdown]
# 9

# %%
N = int(input())
hundreds = N // 100
print(hundreds)
# Out:
# 1000
# 10

# %% [markdown]
# 10

# %%
N = int(input())
units = N % 10
tens = (N // 10) % 10
print(units)
print(tens)
# Out:
# 100
# 0
# 0

# %% [markdown]
# 11

# %%
N = int(input())
hundreds = N // 100
tens = (N // 10) % 10
units = N % 10
sum_digits = hundreds + tens + units
prod_digits = hundreds * tens * units
print(sum_digits)
print(prod_digits)
# Out:
# 1000
# 10
# 0

# %% [markdown]
# 12

# %%
N = int(input())
hundreds = N // 100
tens = (N // 10) % 10
units = N % 10
reversed_num = units * 100 + tens * 10 + hundreds
print(reversed_num)
# Out:
# 1000
# 10

# %% [markdown]
# 13

# %%
N = int(input())
hundreds = N // 100
remainder = N % 100
new_num = remainder * 10 + hundreds
print(new_num)
# Out:
# 1000
# 10

# %% [markdown]
# 14

# %%
N = int(input())
units = N % 10
remainder = N // 10
new_num = units * 100 + remainder
print(new_num)
# Out:
# 100
# 10

# %% [markdown]
# 15

# %% [markdown]
# `

# %%
N = int(input())
hundreds = N // 100
tens = (N // 10) % 10
units = N % 10
new_num = tens * 100 + hundreds * 10 + units
print(new_num)
# Out:
# 1000
# 100

# %% [markdown]
# 16

# %%
N = int(input())
hundreds = N // 100
tens = (N // 10) % 10
units = N % 10
new_num = hundreds * 100 + units * 10 + tens
print(new_num)
# Out:
# 1000
# 1000

# %% [markdown]
# 17

# %%
X = int(input())
temp = X // 100
hundreds = temp % 10
print(hundreds)
# Out:
# 1000
# 0

# %% [markdown]
# 18

# %%
X = int(input())
temp = X // 1000
thousands = temp % 10
print(thousands)
# Out:
# 1000
# 1

# %% [markdown]
# 19

# %%
n = int(input())
print(n // 60)
# Out:
# 1000
# 16

# %% [markdown]
# 20

# %%
n = int(input())
print(n//3600)
# Out:
# 10000
# 2

# %% [markdown]
# 21

# %%
n = int(input())
print(n % 60)
# Out:
# 1000
# 40

# %% [markdown]
# 22

# %%
n = int(input())
print(n % 3600)
# Out:
# 100000
# 2800

# %% [markdown]
# 23

# %%
n = int(input())
print((n % 3600) // 60)
# Out:
# 1000
# 16

# %% [markdown]
# 24

# %%
k = int(input())
print(k % 7)
# Out:
# 1000
# 6

# %% [markdown]
# 25

# %%
k = int(input())
print((k + 3) % 7)
# Out:
# 1000
# 2

# %% [markdown]
# 26

# %%
k = int(input())
print((k - 1) % 7 + 1)
# Out:
# 14
# 7

# %% [markdown]
# 27

# %%
k = int(input())
print((k + 4) % 7 + 1)
# Out:
# 84
# 5

# %% [markdown]
# 28

# %%
k = int(input())
N = int(input())
print((k + N) % 7 + 1)
# Out:
# 100
# 6
# 2

# %% [markdown]
# 29

# %%
a = int(input())
b = int(input())
c = int(input())
squares = (a // c) * (b // c)
area = (a * b) - (squares * c * c)
print(squares)
print(area)
# Out:
# 4
# 6
# 8
# 0
# 24

# %% [markdown]
# 30

# %%
year = int(input())
print((year - 1) // 100 + 1)
# Out:
# 67
# 1
